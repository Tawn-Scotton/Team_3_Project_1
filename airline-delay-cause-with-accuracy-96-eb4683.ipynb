# %% [markdown]
# #Import library

# %%
#import libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sn 
import csv

# %%
#read dataset
df = pd.read_csv("Airline_Delay_Cause.csv")

# %%
#show the first five rows from dataset
df.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2022      5      9E  Endeavor Air Inc.     ABE
# 1  2022      5      9E  Endeavor Air Inc.     ABY
# 2  2022      5      9E  Endeavor Air Inc.     ACK
# 3  2022      5      9E  Endeavor Air Inc.     AEX
# 4  2022      5      9E  Endeavor Air Inc.     AGS
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0        7.0
# 1             Albany, GA: Southwest Georgia Regional         91.0       16.0
# 2                  Nantucket, MA: Nantucket Memorial         19.0        2.0
# 3           Alexandria, LA: Alexandria International         88.0       14.0
# 4        Augusta, GA: Augusta Regional at Bush Field        181.0       19.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        5.95        0.00  ...          0.0              1.00            0.0
# 1        7.38        0.00  ...          0.0              6.09            0.0
# 2        0.13        0.00  ...          0.0              0.88            1.0
# 3        7.26        0.76  ...          0.0              1.64            0.0
# 4       13.84        0.00  ...          0.0              2.09            0.0
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0           0.0      255.0          222.0            0.0        4.0
# 1           0.0      884.0          351.0            0.0       81.0
# 2           0.0      138.0            4.0            0.0      106.0
# 3           0.0      947.0          585.0           35.0      125.0
# 4           0.0      808.0          662.0            0.0       87.0
#
#    security_delay  late_aircraft_delay
# 0             0.0                 29.0
# 1             0.0                452.0
# 2             0.0                 28.0
# 3             0.0                202.0
# 4             0.0                 59.0
#
# [5 rows x 21 columns]

# %% [markdown]
# Data Cleaning

# %%
#discovering if dataset have null value or no
df.isnull()
# Out:
#          year  month  carrier  carrier_name  airport  airport_name  \
# 0       False  False    False         False    False         False
# 1       False  False    False         False    False         False
# 2       False  False    False         False    False         False
# 3       False  False    False         False    False         False
# 4       False  False    False         False    False         False
# ...       ...    ...      ...           ...      ...           ...
# 318012  False  False    False         False    False         False
# 318013  False  False    False         False    False         False
# 318014  False  False    False         False    False         False
# 318015  False  False    False         False    False         False
# 318016  False  False    False         False    False         False
#
#         arr_flights  arr_del15  carrier_ct  weather_ct  ...  security_ct  \
# 0             False      False       False       False  ...        False
# 1             False      False       False       False  ...        False
# 2             False      False       False       False  ...        False
# 3             False      False       False       False  ...        False
# 4             False      False       False       False  ...        False
# ...             ...        ...         ...         ...  ...          ...
# 318012        False      False       False       False  ...        False
# 318013        False      False       False       False  ...        False
# 318014        False      False       False       False  ...        False
# 318015        False      False       False       False  ...        False
# 318016        False      False       False       False  ...        False
#
#         late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0                  False          False         False      False
# 1                  False          False         False      False
# 2                  False          False         False      False
# 3                  False          False         False      False
# 4                  False          False         False      False
# ...                  ...            ...           ...        ...
# 318012             False          False         False      False
# 318013             False          False         False      False
# 318014             False          False         False      False
# 318015             False          False         False      False
# 318016             False          False         False      False
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0               False          False      False           False
# 1               False          False      False           False
# 2               False          False      False           False
# 3               False          False      False           False
# 4               False          False      False           False
# ...               ...            ...        ...             ...
# 318012          False          False      False           False
# 318013          False          False      False           False
# 318014          False          False      False           False
# 318015          False          False      False           False
# 318016          False          False      False           False
#
#         late_aircraft_delay
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 318012                False
# 318013                False
# 318014                False
# 318015                False
# 318016                False
#
# [318017 rows x 21 columns]

# %%
#show the null value in dataset
df.isnull().sum()
# Out:
# year                     0
# month                    0
# carrier                  4
# carrier_name             4
# airport                  3
# airport_name             0
# arr_flights            493
# arr_del15              732
# carrier_ct             492
# weather_ct             494
# nas_ct                 488
# security_ct            488
# late_aircraft_ct       488
# arr_cancelled          488
# arr_diverted           490
# arr_delay              494
# carrier_delay          492
# weather_delay          488
# nas_delay              488
# security_delay         490
# late_aircraft_delay    488
# dtype: int64

# %%
#Remove null values from dataset
df_1=df.dropna(axis=0, how='any', inplace=False)

# %%
#dataset is cleaned from null values
df_1.isnull().sum()
# Out:
# year                   0
# month                  0
# carrier                0
# carrier_name           0
# airport                0
# airport_name           0
# arr_flights            0
# arr_del15              0
# carrier_ct             0
# weather_ct             0
# nas_ct                 0
# security_ct            0
# late_aircraft_ct       0
# arr_cancelled          0
# arr_diverted           0
# arr_delay              0
# carrier_delay          0
# weather_delay          0
# nas_delay              0
# security_delay         0
# late_aircraft_delay    0
# dtype: int64

# %%
#discover if dataset has duplicated values or no 
df_1.duplicated().sum()
# Out:
# 0

# %%
#print types of data in dataset
df_1.dtypes
# Out:
# year                     int64
# month                    int64
# carrier                 object
# carrier_name            object
# airport                 object
# airport_name            object
# arr_flights            float64
# arr_del15              float64
# carrier_ct             float64
# weather_ct             float64
# nas_ct                 float64
# security_ct            float64
# late_aircraft_ct       float64
# arr_cancelled          float64
# arr_diverted           float64
# arr_delay              float64
# carrier_delay          float64
# weather_delay          float64
# nas_delay              float64
# security_delay         float64
# late_aircraft_delay    float64
# dtype: object

# %%
#convert string data in dataset to int 
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
df_1['carrier_name'] = encoder.fit_transform(df_1['carrier_name'])
carrier_name = {index : label for index, label in enumerate(encoder.classes_)}
carrier_name
# Out:
# C:\Users\tscot\AppData\Local\Temp\ipykernel_4404\2594446184.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['carrier_name'] = encoder.fit_transform(df_1['carrier_name'])
# {0: 'ATA Airlines d/b/a ATA',
#  1: 'AirTran Airways Corporation',
#  2: 'Alaska Airlines Inc.',
#  3: 'Allegiant Air',
#  4: 'Aloha Airlines Inc.',
#  5: 'America West Airlines Inc.',
#  6: 'American Airlines Inc.',
#  7: 'American Eagle Airlines Inc.',
#  8: 'Atlantic Coast Airlines',
#  9: 'Atlantic Southeast Airlines',
#  10: 'Comair Inc.',
#  11: 'Continental Air Lines Inc.',
#  12: 'Delta Air Lines Inc.',
#  13: 'Endeavor Air Inc.',
#  14: 'Envoy Air',
#  15: 'ExpressJet Airlines Inc.',
#  16: 'ExpressJet Airlines LLC',
#  17: 'Frontier Airlines Inc.',
#  18: 'Hawaiian Airlines Inc.',
#  19: 'Horizon Air',
#  20: 'Independence Air',
#  21: 'JetBlue Airways',
#  22: 'Mesa Airlines Inc.',
#  23: 'Northwest Airlines Inc.',
#  24: 'PSA Airlines Inc.',
#  25: 'Pinnacle Airlines Inc.',
#  26: 'Republic Airline',
#  27: 'SkyWest Airlines Inc.',
#  28: 'Southwest Airlines Co.',
#  29: 'Spirit Air Lines',
#  30: 'US Airways Inc.',
#  31: 'United Air Lines Inc.',
#  32: 'Virgin America'}

# %%
df_1['airport'] = encoder.fit_transform(df_1['airport'])
airport = {index : label for index, label in enumerate(encoder.classes_)}
airport
# Out:
# C:\Users\tscot\AppData\Local\Temp\ipykernel_4404\4136530110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['airport'] = encoder.fit_transform(df_1['airport'])
# {0: 'ABE',
#  1: 'ABI',
#  2: 'ABQ',
#  3: 'ABR',
#  4: 'ABY',
#  5: 'ACK',
#  6: 'ACT',
#  7: 'ACV',
#  8: 'ACY',
#  9: 'ADK',
#  10: 'ADQ',
#  11: 'AEX',
#  12: 'AGS',
#  13: 'AKN',
#  14: 'ALB',
#  15: 'ALO',
#  16: 'ALS',
#  17: 'ALW',
#  18: 'AMA',
#  19: 'ANC',
#  20: 'APF',
#  21: 'APN',
#  22: 'ART',
#  23: 'ASE',
#  24: 'ATL',
#  25: 'ATW',
#  26: 'ATY',
#  27: 'AUS',
#  28: 'AVL',
#  29: 'AVP',
#  30: 'AZA',
#  31: 'AZO',
#  32: 'BDL',
#  33: 'BET',
#  34: 'BFF',
#  35: 'BFL',
#  36: 'BFM',
#  37: 'BGM',
#  38: 'BGR',
#  39: 'BHM',
#  40: 'BIH',
#  41: 'BIL',
#  42: 'BIS',
#  43: 'BJI',
#  44: 'BKG',
#  45: 'BLI',
#  46: 'BLV',
#  47: 'BMI',
#  48: 'BNA',
#  49: 'BOI',
#  50: 'BOS',
#  51: 'BPT',
#  52: 'BQK',
#  53: 'BQN',
#  54: 'BRD',
#  55: 'BRO',
#  56: 'BRW',
#  57: 'BTM',
#  58: 'BTR',
#  59: 'BTV',
#  60: 'BUF',
#  61: 'BUR',
#  62: 'BWI',
#  63: 'BZN',
#  64: 'CAE',
#  65: 'CAK',
#  66: 'CBM',
#  67: 'CDB',
#  68: 'CDC',
#  69: 'CDV',
#  70: 'CEC',
#  71: 'CGI',
#  72: 'CHA',
#  73: 'CHO',
#  74: 'CHS',
#  75: 'CIC',
#  76: 'CID',
#  77: 'CIU',
#  78: 'CKB',
#  79: 'CLD',
#  80: 'CLE',
#  81: 'CLL',
#  82: 'CLT',
#  83: 'CMH',
#  84: 'CMI',
#  85: 'CMX',
#  86: 'CNY',
#  87: 'COD',
#  88: 'COS',
#  89: 'COU',
#  90: 'CPR',
#  91: 'CRP',
#  92: 'CRW',
#  93: 'CSG',
#  94: 'CVG',
#  95: 'CWA',
#  96: 'CYS',
#  97: 'DAB',
#  98: 'DAL',
#  99: 'DAY',
#  100: 'DBQ',
#  101: 'DCA',
#  102: 'DDC',
#  103: 'DEC',
#  104: 'DEN',
#  105: 'DFW',
#  106: 'DHN',
#  107: 'DIK',
#  108: 'DLG',
#  109: 'DLH',
#  110: 'DRO',
#  111: 'DRT',
#  112: 'DSM',
#  113: 'DTW',
#  114: 'DUT',
#  115: 'DVL',
#  116: 'EAR',
#  117: 'EAT',
#  118: 'EAU',
#  119: 'ECP',
#  120: 'EFD',
#  121: 'EGE',
#  122: 'EKO',
#  123: 'ELM',
#  124: 'ELP',
#  125: 'ERI',
#  126: 'ESC',
#  127: 'EUG',
#  128: 'EVV',
#  129: 'EWN',
#  130: 'EWR',
#  131: 'EYW',
#  132: 'FAI',
#  133: 'FAR',
#  134: 'FAT',
#  135: 'FAY',
#  136: 'FCA',
#  137: 'FLG',
#  138: 'FLL',
#  139: 'FLO',
#  140: 'FMN',
#  141: 'FNL',
#  142: 'FNT',
#  143: 'FOD',
#  144: 'FOE',
#  145: 'FSD',
#  146: 'FSM',
#  147: 'FWA',
#  148: 'GCC',
#  149: 'GCK',
#  150: 'GEG',
#  151: 'GFK',
#  152: 'GGG',
#  153: 'GJT',
#  154: 'GLH',
#  155: 'GNV',
#  156: 'GPT',
#  157: 'GRB',
#  158: 'GRI',
#  159: 'GRK',
#  160: 'GRR',
#  161: 'GSO',
#  162: 'GSP',
#  163: 'GST',
#  164: 'GTF',
#  165: 'GTR',
#  166: 'GUC',
#  167: 'GUM',
#  168: 'HDN',
#  169: 'HGR',
#  170: 'HHH',
#  171: 'HIB',
#  172: 'HKY',
#  173: 'HLN',
#  174: 'HNL',
#  175: 'HOB',
#  176: 'HOU',
#  177: 'HPN',
#  178: 'HRL',
#  179: 'HSV',
#  180: 'HTS',
#  181: 'HVN',
#  182: 'HYA',
#  183: 'HYS',
#  184: 'IAD',
#  185: 'IAG',
#  186: 'IAH',
#  187: 'ICT',
#  188: 'IDA',
#  189: 'IFP',
#  190: 'ILE',
#  191: 'ILG',
#  192: 'ILM',
#  193: 'IMT',
#  194: 'IND',
#  195: 'INL',
#  196: 'IPL',
#  197: 'IPT',
#  198: 'ISN',
#  199: 'ISO',
#  200: 'ISP',
#  201: 'ITH',
#  202: 'ITO',
#  203: 'IYK',
#  204: 'JAC',
#  205: 'JAN',
#  206: 'JAX',
#  207: 'JFK',
#  208: 'JLN',
#  209: 'JMS',
#  210: 'JNU',
#  211: 'JST',
#  212: 'KOA',
#  213: 'KTN',
#  214: 'LAN',
#  215: 'LAR',
#  216: 'LAS',
#  217: 'LAW',
#  218: 'LAX',
#  219: 'LBB',
#  220: 'LBE',
#  221: 'LBF',
#  222: 'LBL',
#  223: 'LCH',
#  224: 'LCK',
#  225: 'LEX',
#  226: 'LFT',
#  227: 'LGA',
#  228: 'LGB',
#  229: 'LIH',
#  230: 'LIT',
#  231: 'LMT',
#  232: 'LNK',
#  233: 'LNY',
#  234: 'LRD',
#  235: 'LSE',
#  236: 'LWB',
#  237: 'LWS',
#  238: 'LYH',
#  239: 'MAF',
#  240: 'MBS',
#  241: 'MCI',
#  242: 'MCN',
#  243: 'MCO',
#  244: 'MCW',
#  245: 'MDT',
#  246: 'MDW',
#  247: 'MEI',
#  248: 'MEM',
#  249: 'MFE',
#  250: 'MFR',
#  251: 'MGM',
#  252: 'MHK',
#  253: 'MHT',
#  254: 'MIA',
#  255: 'MKC',
#  256: 'MKE',
#  257: 'MKG',
#  258: 'MKK',
#  259: 'MLB',
#  260: 'MLI',
#  261: 'MLU',
#  262: 'MMH',
#  263: 'MOB',
#  264: 'MOD',
#  265: 'MOT',
#  266: 'MQT',
#  267: 'MRY',
#  268: 'MSN',
#  269: 'MSO',
#  270: 'MSP',
#  271: 'MSY',
#  272: 'MTH',
#  273: 'MTJ',
#  274: 'MVY',
#  275: 'MWH',
#  276: 'MYR',
#  277: 'OAJ',
#  278: 'OAK',
#  279: 'OGD',
#  280: 'OGG',
#  281: 'OGS',
#  282: 'OKC',
#  283: 'OMA',
#  284: 'OME',
#  285: 'ONT',
#  286: 'ORD',
#  287: 'ORF',
#  288: 'ORH',
#  289: 'OTH',
#  290: 'OTZ',
#  291: 'OWB',
#  292: 'OXR',
#  293: 'PAE',
#  294: 'PAH',
#  295: 'PBG',
#  296: 'PBI',
#  297: 'PDX',
#  298: 'PFN',
#  299: 'PGD',
#  300: 'PGV',
#  301: 'PHF',
#  302: 'PHL',
#  303: 'PHX',
#  304: 'PIA',
#  305: 'PIB',
#  306: 'PIE',
#  307: 'PIH',
#  308: 'PIR',
#  309: 'PIT',
#  310: 'PLN',
#  311: 'PMD',
#  312: 'PNS',
#  313: 'PPG',
#  314: 'PRC',
#  315: 'PSC',
#  316: 'PSE',
#  317: 'PSG',
#  318: 'PSM',
#  319: 'PSP',
#  320: 'PUB',
#  321: 'PUW',
#  322: 'PVD',
#  323: 'PVU',
#  324: 'PWM',
#  325: 'RAP',
#  326: 'RCA',
#  327: 'RDD',
#  328: 'RDM',
#  329: 'RDU',
#  330: 'RFD',
#  331: 'RHI',
#  332: 'RIC',
#  333: 'RIW',
#  334: 'RKS',
#  335: 'RNO',
#  336: 'ROA',
#  337: 'ROC',
#  338: 'ROW',
#  339: 'RST',
#  340: 'RSW',
#  341: 'SAF',
#  342: 'SAN',
#  343: 'SAT',
#  344: 'SAV',
#  345: 'SBA',
#  346: 'SBN',
#  347: 'SBP',
#  348: 'SCC',
#  349: 'SCE',
#  350: 'SCK',
#  351: 'SDF',
#  352: 'SEA',
#  353: 'SFB',
#  354: 'SFO',
#  355: 'SGF',
#  356: 'SGU',
#  357: 'SHD',
#  358: 'SHR',
#  359: 'SHV',
#  360: 'SIT',
#  361: 'SJC',
#  362: 'SJT',
#  363: 'SJU',
#  364: 'SKA',
#  365: 'SLC',
#  366: 'SLE',
#  367: 'SLN',
#  368: 'SMF',
#  369: 'SMX',
#  370: 'SNA',
#  371: 'SOP',
#  372: 'SPI',
#  373: 'SPN',
#  374: 'SPS',
#  375: 'SRQ',
#  376: 'STC',
#  377: 'STL',
#  378: 'STS',
#  379: 'STT',
#  380: 'STX',
#  381: 'SUN',
#  382: 'SUX',
#  383: 'SWF',
#  384: 'SWO',
#  385: 'SYR',
#  386: 'TBN',
#  387: 'TEX',
#  388: 'TLH',
#  389: 'TOL',
#  390: 'TPA',
#  391: 'TRI',
#  392: 'TTN',
#  393: 'TUL',
#  394: 'TUP',
#  395: 'TUS',
#  396: 'TVC',
#  397: 'TWF',
#  398: 'TXK',
#  399: 'TYR',
#  400: 'TYS',
#  401: 'UIN',
#  402: 'USA',
#  403: 'UST',
#  404: 'UTM',
#  405: 'VCT',
#  406: 'VEL',
#  407: 'VIS',
#  408: 'VLD',
#  409: 'VPS',
#  410: 'WRG',
#  411: 'WYS',
#  412: 'XNA',
#  413: 'XWA',
#  414: 'YAK',
#  415: 'YKM',
#  416: 'YNG',
#  417: 'YUM'}

# %%
df_1['airport_name'] = encoder.fit_transform(df_1['airport_name'])
airport_name = {index : label for index, label in enumerate(encoder.classes_)}
airport_name
# Out:
# C:\Users\tscot\AppData\Local\Temp\ipykernel_4404\110047566.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['airport_name'] = encoder.fit_transform(df_1['airport_name'])
# {0: 'Aberdeen, SD: Aberdeen Regional',
#  1: 'Abilene, TX: Abilene Regional',
#  2: 'Adak Island, AK: Adak',
#  3: 'Aguadilla, PR: Rafael Hernandez',
#  4: 'Akron, OH: Akron-Canton Regional',
#  5: 'Alamosa, CO: San Luis Valley Regional/Bergman Field',
#  6: 'Albany, GA: Southwest Georgia Regional',
#  7: 'Albany, NY: Albany International',
#  8: 'Albuquerque, NM: Albuquerque International Sunport',
#  9: 'Alexandria, LA: Alexandria International',
#  10: 'Allentown/Bethlehem/Easton, PA: Lehigh Valley International',
#  11: 'Alpena, MI: Alpena County Regional',
#  12: 'Amarillo, TX: Rick Husband Amarillo International',
#  13: 'Anchorage, AK: Ted Stevens Anchorage International',
#  14: 'Appleton, WI: Appleton International',
#  15: 'Arcata/Eureka, CA: California Redwood Coast Humboldt County',
#  16: 'Asheville, NC: Asheville Regional',
#  17: 'Ashland, WV: Tri-State/Milton J. Ferguson Field',
#  18: 'Aspen, CO: Aspen Pitkin County Sardy Field',
#  19: 'Atlanta, GA: Hartsfield-Jackson Atlanta International',
#  20: 'Atlantic City, NJ: Atlantic City International',
#  21: 'Augusta, GA: Augusta Regional at Bush Field',
#  22: 'Austin, TX: Austin - Bergstrom International',
#  23: 'Bakersfield, CA: Meadows Field',
#  24: 'Baltimore, MD: Baltimore/Washington International Thurgood Marshall',
#  25: 'Bangor, ME: Bangor International',
#  26: 'Barrow, AK: Wiley Post/Will Rogers Memorial',
#  27: 'Baton Rouge, LA: Baton Rouge Metropolitan/Ryan Field',
#  28: 'Beaumont/Port Arthur, TX: Jack Brooks Regional',
#  29: 'Belleville, IL: Scott AFB/MidAmerica',
#  30: 'Bellingham, WA: Bellingham International',
#  31: 'Bemidji, MN: Bemidji Regional',
#  32: 'Bend/Redmond, OR: Roberts Field',
#  33: 'Bethel, AK: Bethel Airport',
#  34: 'Billings, MT: Billings Logan International',
#  35: 'Binghamton, NY: Greater Binghamton/Edwin A. Link Field',
#  36: 'Birmingham, AL: Birmingham-Shuttlesworth International',
#  37: 'Bishop, CA: Bishop Airport',
#  38: 'Bismarck/Mandan, ND: Bismarck Municipal',
#  39: 'Bloomington/Normal, IL: Central Il Regional Airport at Bloomington',
#  40: 'Boise, ID: Boise Air Terminal',
#  41: 'Boston, MA: Logan International',
#  42: 'Bozeman, MT: Bozeman Yellowstone International',
#  43: 'Brainerd, MN: Brainerd Lakes Regional',
#  44: 'Branson, MO: Branson Airport',
#  45: 'Bristol/Johnson City/Kingsport, TN: Tri Cities',
#  46: 'Brownsville, TX: Brownsville South Padre Island International',
#  47: 'Brunswick, GA: Brunswick Golden Isles',
#  48: 'Buffalo, NY: Buffalo Niagara International',
#  49: 'Bullhead City, AZ: Laughlin/Bullhead International',
#  50: 'Burbank, CA: Bob Hope',
#  51: 'Burlington, VT: Burlington International',
#  52: 'Butte, MT: Bert Mooney',
#  53: 'Cape Girardeau, MO: Cape Girardeau Regional',
#  54: 'Carlsbad, CA: McClellan-Palomar',
#  55: 'Casper, WY: Casper/Natrona County International',
#  56: 'Cedar City, UT: Cedar City Regional',
#  57: 'Cedar Rapids/Iowa City, IA: The Eastern Iowa',
#  58: 'Champaign/Urbana, IL: University of Illinois/Willard',
#  59: 'Charleston, SC: Charleston AFB/International',
#  60: 'Charleston/Dunbar, WV: Yeager',
#  61: 'Charlotte Amalie, VI: Cyril E King',
#  62: 'Charlotte, NC: Charlotte Douglas International',
#  63: 'Charlottesville, VA: Charlottesville Albemarle',
#  64: 'Chattanooga, TN: Lovell Field',
#  65: 'Cheyenne, WY: Cheyenne Regional/Jerry Olson Field',
#  66: 'Chicago, IL: Chicago Midway International',
#  67: "Chicago, IL: Chicago O'Hare International",
#  68: 'Chico, CA: Chico Municipal',
#  69: 'Christiansted, VI: Henry E. Rohlsen',
#  70: 'Cincinnati, OH: Cincinnati/Northern Kentucky International',
#  71: 'Clarksburg/Fairmont, WV: North Central West Virginia',
#  72: 'Cleveland, OH: Cleveland-Hopkins International',
#  73: 'Cody, WY: Yellowstone Regional',
#  74: 'Cold Bay, AK: Cold Bay Airport',
#  75: 'College Station/Bryan, TX: Easterwood Field',
#  76: 'Colorado Springs, CO: City of Colorado Springs Municipal',
#  77: 'Columbia, MO: Columbia Regional',
#  78: 'Columbia, SC: Columbia Metropolitan',
#  79: 'Columbus, GA: Columbus Airport',
#  80: 'Columbus, MS: Columbus AFB',
#  81: 'Columbus, MS: Golden Triangle Regional',
#  82: 'Columbus, OH: John Glenn Columbus International',
#  83: 'Columbus, OH: Rickenbacker International',
#  84: 'Concord, NC: Concord Padgett Regional',
#  85: 'Cordova, AK: Merle K Mudhole Smith',
#  86: 'Corpus Christi, TX: Corpus Christi International',
#  87: 'Crescent City, CA: Jack McNamara Field',
#  88: 'Dallas, TX: Dallas Love Field',
#  89: 'Dallas/Fort Worth, TX: Dallas/Fort Worth International',
#  90: 'Dayton, OH: James M Cox/Dayton International',
#  91: 'Daytona Beach, FL: Daytona Beach International',
#  92: 'Deadhorse, AK: Deadhorse Airport',
#  93: 'Decatur, IL: Decatur Airport',
#  94: 'Del Rio, TX: Del Rio International',
#  95: 'Denver, CO: Denver International',
#  96: 'Des Moines, IA: Des Moines International',
#  97: 'Detroit, MI: Detroit Metro Wayne County',
#  98: 'Devils Lake, ND: Devils Lake Regional',
#  99: 'Dickinson, ND: Dickinson - Theodore Roosevelt Regional',
#  100: 'Dillingham, AK: Dillingham Airport',
#  101: 'Dodge City, KS: Dodge City Regional',
#  102: 'Dothan, AL: Dothan Regional',
#  103: 'Dubuque, IA: Dubuque Regional',
#  104: 'Duluth, MN: Duluth International',
#  105: 'Durango, CO: Durango La Plata County',
#  106: 'Eagle, CO: Eagle County Regional',
#  107: 'Eau Claire, WI: Chippewa Valley Regional',
#  108: 'El Centro, CA: Imperial County',
#  109: 'El Paso, TX: El Paso International',
#  110: 'Elko, NV: Elko Regional',
#  111: 'Elmira/Corning, NY: Elmira/Corning Regional',
#  112: 'Erie, PA: Erie International/Tom Ridge Field',
#  113: 'Escanaba, MI: Delta County',
#  114: 'Eugene, OR: Mahlon Sweet Field',
#  115: 'Evansville, IN: Evansville Regional',
#  116: 'Everett, WA: Snohomish County',
#  117: 'Fairbanks, AK: Fairbanks International',
#  118: 'Fargo, ND: Hector International',
#  119: 'Farmington, NM: Four Corners Regional',
#  120: 'Fayetteville, AR: Northwest Arkansas Regional',
#  121: 'Fayetteville, NC: Fayetteville Regional/Grannis Field',
#  122: 'Flagstaff, AZ: Flagstaff Pulliam',
#  123: 'Flint, MI: Bishop International',
#  124: 'Florence, SC: Florence Regional',
#  125: 'Fort Collins/Loveland, CO: Northern Colorado Regional',
#  126: 'Fort Dodge, IA: Fort Dodge Regional',
#  127: 'Fort Lauderdale, FL: Fort Lauderdale-Hollywood International',
#  128: 'Fort Leonard Wood, MO: Waynesville-St. Robert Regional Forney Field',
#  129: 'Fort Myers, FL: Southwest Florida International',
#  130: 'Fort Smith, AR: Fort Smith Regional',
#  131: 'Fort Wayne, IN: Fort Wayne International',
#  132: 'Fresno, CA: Fresno Yosemite International',
#  133: 'Gainesville, FL: Gainesville Regional',
#  134: 'Garden City, KS: Garden City Regional',
#  135: 'Gillette, WY: Gillette Campbell County',
#  136: 'Grand Forks, ND: Grand Forks International',
#  137: 'Grand Island, NE: Central Nebraska Regional',
#  138: 'Grand Junction, CO: Grand Junction Regional',
#  139: 'Grand Rapids, MI: Gerald R. Ford International',
#  140: 'Great Falls, MT: Great Falls International',
#  141: 'Green Bay, WI: Green Bay Austin Straubel International',
#  142: 'Greensboro/High Point, NC: Piedmont Triad International',
#  143: 'Greenville, MS: Greenville Mid Delta',
#  144: 'Greenville, NC: Pitt Greenville',
#  145: 'Greer, SC: Greenville-Spartanburg International',
#  146: 'Guam, TT: Guam International',
#  147: 'Gulfport/Biloxi, MS: Gulfport-Biloxi International',
#  148: 'Gunnison, CO: Gunnison-Crested Butte Regional',
#  149: 'Gustavus, AK: Gustavus Airport',
#  150: 'Hagerstown, MD: Hagerstown Regional-Richard A. Henson Field',
#  151: 'Hancock/Houghton, MI: Houghton County Memorial',
#  152: 'Harlingen/San Benito, TX: Valley International',
#  153: 'Harrisburg, PA: Harrisburg International',
#  154: 'Hartford, CT: Bradley International',
#  155: 'Hattiesburg/Laurel, MS: Hattiesburg-Laurel Regional',
#  156: 'Hayden, CO: Yampa Valley',
#  157: 'Hays, KS: Hays Regional',
#  158: 'Helena, MT: Helena Regional',
#  159: 'Hibbing, MN: Range Regional',
#  160: 'Hickory, NC: Hickory Regional',
#  161: 'Hilo, HI: Hilo International',
#  162: 'Hilton Head, SC: Hilton Head Airport',
#  163: 'Hobbs, NM: Lea County Regional',
#  164: 'Honolulu, HI: Daniel K Inouye International',
#  165: 'Hoolehua, HI: Molokai',
#  166: 'Houston, TX: Ellington',
#  167: 'Houston, TX: George Bush Intercontinental/Houston',
#  168: 'Houston, TX: William P Hobby',
#  169: 'Huntsville, AL: Huntsville International-Carl T Jones Field',
#  170: 'Hyannis, MA: Barnstable Municipal-Boardman/Polando Field',
#  171: 'Idaho Falls, ID: Idaho Falls Regional',
#  172: 'Indianapolis, IN: Indianapolis International',
#  173: 'International Falls, MN: Falls International Einarson Field',
#  174: 'Inyokern, CA: Inyokern Airport',
#  175: 'Iron Mountain/Kingsfd, MI: Ford',
#  176: 'Islip, NY: Long Island MacArthur',
#  177: 'Ithaca/Cortland, NY: Ithaca Tompkins Regional',
#  178: 'Jackson, WY: Jackson Hole',
#  179: 'Jackson/Vicksburg, MS: Jackson Medgar Wiley Evers International',
#  180: 'Jacksonville, FL: Jacksonville International',
#  181: 'Jacksonville/Camp Lejeune, NC: Albert J Ellis',
#  182: 'Jamestown, ND: Jamestown Regional',
#  183: 'Johnstown, PA: John Murtha Johnstown-Cambria County',
#  184: 'Joplin, MO: Joplin Regional',
#  185: 'Juneau, AK: Juneau International',
#  186: 'Kahului, HI: Kahului Airport',
#  187: 'Kalamazoo, MI: Kalamazoo/Battle Creek International',
#  188: 'Kalispell, MT: Glacier Park International',
#  189: 'Kansas City, MO: Charles B. Wheeler Downtown',
#  190: 'Kansas City, MO: Kansas City International',
#  191: 'Kearney, NE: Kearney Regional',
#  192: 'Ketchikan, AK: Ketchikan International',
#  193: 'Key West, FL: Key West International',
#  194: 'Killeen, TX: Robert Gray AAF',
#  195: 'Killeen, TX: Skylark Field',
#  196: 'King Salmon, AK: King Salmon Airport',
#  197: 'Kinston, NC: Kinston Regional Jetport at Stallings Field',
#  198: 'Klamath Falls, OR: Crater Lake Klamath Regional',
#  199: 'Knoxville, TN: McGhee Tyson',
#  200: 'Kodiak, AK: Kodiak Airport',
#  201: 'Kona, HI: Ellison Onizuka Kona International at Keahole',
#  202: 'Kotzebue, AK: Ralph Wien Memorial',
#  203: 'La Crosse, WI: La Crosse Regional',
#  204: 'Lafayette, LA: Lafayette Regional Paul Fournet Field',
#  205: 'Lake Charles, LA: Lake Charles Regional',
#  206: 'Lanai, HI: Lanai Airport',
#  207: 'Lansing, MI: Capital Region International',
#  208: 'Laramie, WY: Laramie Regional',
#  209: 'Laredo, TX: Laredo International',
#  210: 'Las Vegas, NV: McCarran International',
#  211: 'Latrobe, PA: Arnold Palmer Regional',
#  212: 'Lawton/Fort Sill, OK: Lawton-Fort Sill Regional',
#  213: 'Lewisburg, WV: Greenbrier Valley',
#  214: 'Lewiston, ID: Lewiston Nez Perce County',
#  215: 'Lexington, KY: Blue Grass',
#  216: 'Liberal, KS: Liberal Mid-America Regional',
#  217: 'Lihue, HI: Lihue Airport',
#  218: 'Lincoln, NE: Lincoln Airport',
#  219: 'Little Rock, AR: Bill and Hillary Clinton Nat Adams Field',
#  220: 'Long Beach, CA: Long Beach Airport',
#  221: 'Longview, TX: East Texas Regional',
#  222: 'Los Angeles, CA: Los Angeles International',
#  223: 'Louisville, KY: Louisville Muhammad Ali International',
#  224: 'Lubbock, TX: Lubbock Preston Smith International',
#  225: 'Lynchburg, VA: Lynchburg Regional/Preston Glenn Field',
#  226: 'Macon, GA: Middle Georgia Regional',
#  227: 'Madison, WI: Dane County Regional-Truax Field',
#  228: 'Mammoth Lakes, CA: Mammoth Lakes Airport',
#  229: 'Manchester, NH: Manchester-Boston Regional',
#  230: 'Manhattan/Ft. Riley, KS: Manhattan Regional',
#  231: 'Marathon, FL: The Florida Keys Marathon International',
#  232: 'Marquette, MI: Sawyer International',
#  233: "Martha's Vineyard, MA: Martha's Vineyard Airport",
#  234: 'Mason City, IA: Mason City Municipal',
#  235: 'Medford, OR: Rogue Valley International - Medford',
#  236: 'Melbourne, FL: Melbourne International',
#  237: 'Memphis, TN: Memphis International',
#  238: 'Meridian, MS: Key Field',
#  239: 'Miami, FL: Miami International',
#  240: 'Midland/Odessa, TX: Midland International Air and Space Port',
#  241: 'Milwaukee, WI: General Mitchell International',
#  242: 'Minneapolis, MN: Minneapolis-St Paul International',
#  243: 'Minot, ND: Minot International',
#  244: 'Mission/McAllen/Edinburg, TX: McAllen Miller International',
#  245: 'Missoula, MT: Missoula International',
#  246: 'Moab, UT: Canyonlands Field',
#  247: 'Mobile, AL: Mobile Downtown',
#  248: 'Mobile, AL: Mobile Regional',
#  249: 'Modesto, CA: Modesto City-County-Harry Sham Field',
#  250: 'Moline, IL: Quad City International',
#  251: 'Monroe, LA: Monroe Regional',
#  252: 'Monterey, CA: Monterey Regional',
#  253: 'Montgomery, AL: Montgomery Regional',
#  254: 'Montrose/Delta, CO: Montrose Regional',
#  255: 'Moses Lake, WA: Grant County International',
#  256: 'Mosinee, WI: Central Wisconsin',
#  257: 'Muskegon, MI: Muskegon County',
#  258: 'Myrtle Beach, SC: Myrtle Beach International',
#  259: 'Nantucket, MA: Nantucket Memorial',
#  260: 'Naples, FL: Naples Municipal',
#  261: 'Nashville, TN: Nashville International',
#  262: 'New Bern/Morehead/Beaufort, NC: Coastal Carolina Regional',
#  263: 'New Haven, CT: Tweed New Haven',
#  264: 'New Orleans, LA: Louis Armstrong New Orleans International',
#  265: 'New York, NY: John F. Kennedy International',
#  266: 'New York, NY: LaGuardia',
#  267: 'Newark, NJ: Newark Liberty International',
#  268: 'Newburgh/Poughkeepsie, NY: New York Stewart International',
#  269: 'Newport News/Williamsburg, VA: Newport News/Williamsburg International',
#  270: 'Niagara Falls, NY: Niagara Falls International',
#  271: 'Nome, AK: Nome Airport',
#  272: 'Norfolk, VA: Norfolk International',
#  273: 'North Bend/Coos Bay, OR: Southwest Oregon Regional',
#  274: 'North Platte, NE: North Platte Regional Airport Lee Bird Field',
#  275: 'Oakland, CA: Metropolitan Oakland International',
#  276: 'Ogden, UT: Ogden-Hinckley',
#  277: 'Ogdensburg, NY: Ogdensburg International',
#  278: 'Oklahoma City, OK: Will Rogers World',
#  279: 'Omaha, NE: Eppley Airfield',
#  280: 'Ontario, CA: Ontario International',
#  281: 'Orlando, FL: Orlando International',
#  282: 'Owensboro, KY: Owensboro Daviess County Regional',
#  283: 'Oxnard/Ventura, CA: Oxnard',
#  284: 'Paducah, KY: Barkley Regional',
#  285: 'Pago Pago, TT: Pago Pago International',
#  286: 'Palm Springs, CA: Palm Springs International',
#  287: 'Palmdale, CA: Palmdale USAF Plant 42',
#  288: 'Panama City, FL: Bay County',
#  289: 'Panama City, FL: Northwest Florida Beaches International',
#  290: 'Pasco/Kennewick/Richland, WA: Tri Cities',
#  291: 'Pellston, MI: Pellston Regional Airport of Emmet County',
#  292: 'Pensacola, FL: Pensacola International',
#  293: 'Peoria, IL: General Downing - Peoria International',
#  294: 'Petersburg, AK: Petersburg James A Johnson',
#  295: 'Philadelphia, PA: Philadelphia International',
#  296: 'Phoenix, AZ: Phoenix - Mesa Gateway',
#  297: 'Phoenix, AZ: Phoenix Sky Harbor International',
#  298: 'Pierre, SD: Pierre Regional',
#  299: 'Pinehurst/Southern Pines, NC: Moore County',
#  300: 'Pittsburgh, PA: Pittsburgh International',
#  301: 'Plattsburgh, NY: Plattsburgh International',
#  302: 'Pocatello, ID: Pocatello Regional',
#  303: 'Ponce, PR: Mercedita',
#  304: 'Portland, ME: Portland International Jetport',
#  305: 'Portland, OR: Portland International',
#  306: 'Portsmouth, NH: Portsmouth International at Pease',
#  307: 'Prescott, AZ: Prescott Regional Ernest A Love Field',
#  308: 'Providence, RI: Theodore Francis Green State',
#  309: 'Provo, UT: Provo Municipal',
#  310: 'Pueblo, CO: Pueblo Memorial',
#  311: 'Pullman, WA: Pullman Moscow Regional',
#  312: 'Punta Gorda, FL: Punta Gorda Airport',
#  313: 'Quincy, IL: Quincy Regional-Baldwin Field',
#  314: 'Raleigh/Durham, NC: Raleigh-Durham International',
#  315: 'Rapid City, SD: Ellsworth AFB',
#  316: 'Rapid City, SD: Rapid City Regional',
#  317: 'Redding, CA: Redding Municipal',
#  318: 'Reno, NV: Reno/Tahoe International',
#  319: 'Rhinelander, WI: Rhinelander/Oneida County',
#  320: 'Richmond, VA: Richmond International',
#  321: 'Riverton/Lander, WY: Riverton Regional',
#  322: 'Roanoke, VA: Roanoke Blacksburg Regional Woodrum Field',
#  323: 'Rochester, MN: Rochester International',
#  324: 'Rochester, NY: Greater Rochester International',
#  325: 'Rock Springs, WY: Southwest Wyoming Regional',
#  326: 'Rockford, IL: Chicago/Rockford International',
#  327: 'Roswell, NM: Roswell International Air Center',
#  328: 'Sacramento, CA: Sacramento International',
#  329: 'Saginaw/Bay City/Midland, MI: MBS International',
#  330: 'Saipan, TT: Francisco C. Ada Saipan International',
#  331: 'Salem, OR: McNary Field',
#  332: 'Salina, KS: Salina Regional',
#  333: 'Salt Lake City, UT: Salt Lake City International',
#  334: 'San Angelo, TX: San Angelo Regional/Mathis Field',
#  335: 'San Antonio, TX: San Antonio International',
#  336: 'San Diego, CA: San Diego International',
#  337: 'San Francisco, CA: San Francisco International',
#  338: 'San Jose, CA: Norman Y. Mineta San Jose International',
#  339: 'San Juan, PR: Luis Munoz Marin International',
#  340: 'San Luis Obispo, CA: San Luis County Regional',
#  341: 'Sanford, FL: Orlando Sanford International',
#  342: 'Santa Ana, CA: John Wayne Airport-Orange County',
#  343: 'Santa Barbara, CA: Santa Barbara Municipal',
#  344: 'Santa Fe, NM: Santa Fe Municipal',
#  345: 'Santa Maria, CA: Santa Maria Public/Capt. G. Allan Hancock Field',
#  346: 'Santa Rosa, CA: Charles M. Schulz - Sonoma County',
#  347: 'Sarasota/Bradenton, FL: Sarasota/Bradenton International',
#  348: 'Sault Ste. Marie, MI: Chippewa County International',
#  349: 'Savannah, GA: Savannah/Hilton Head International',
#  350: 'Scottsbluff, NE: Western Neb. Regional/William B. Heilig Field',
#  351: 'Scranton/Wilkes-Barre, PA: Wilkes Barre Scranton International',
#  352: 'Seattle, WA: Seattle/Tacoma International',
#  353: 'Sheridan, WY: Sheridan County',
#  354: 'Shreveport, LA: Shreveport Regional',
#  355: 'Sioux City, IA: Sioux Gateway Brig Gen Bud Day Field',
#  356: 'Sioux Falls, SD: Joe Foss Field',
#  357: 'Sitka, AK: Sitka Rocky Gutierrez',
#  358: 'South Bend, IN: South Bend International',
#  359: 'Spokane, WA: Fairchild AFB',
#  360: 'Spokane, WA: Spokane International',
#  361: 'Springfield, IL: Abraham Lincoln Capital',
#  362: 'Springfield, MO: Springfield-Branson National',
#  363: 'St. Augustine, FL: Northeast Florida Regional',
#  364: 'St. Cloud, MN: St. Cloud Regional',
#  365: 'St. George, UT: St George Regional',
#  366: 'St. Louis, MO: St Louis Lambert International',
#  367: 'St. Petersburg, FL: St Pete Clearwater International',
#  368: 'State College, PA: University Park',
#  369: 'Staunton, VA: Shenandoah Valley Regional',
#  370: 'Stillwater, OK: Stillwater Regional',
#  371: 'Stockton, CA: Stockton Metropolitan',
#  372: 'Sun Valley/Hailey/Ketchum, ID: Friedman Memorial',
#  373: 'Syracuse, NY: Syracuse Hancock International',
#  374: 'Tallahassee, FL: Tallahassee International',
#  375: 'Tampa, FL: Tampa International',
#  376: 'Telluride, CO: Telluride Regional',
#  377: 'Texarkana, AR: Texarkana Regional-Webb Field',
#  378: 'Toledo, OH: Toledo Express',
#  379: 'Topeka, KS: Topeka Regional',
#  380: 'Traverse City, MI: Cherry Capital',
#  381: 'Trenton, NJ: Trenton Mercer',
#  382: 'Tucson, AZ: Tucson International',
#  383: 'Tulsa, OK: Tulsa International',
#  384: 'Tunica, MS: Tunica Municipal',
#  385: 'Tupelo, MS: Tupelo Regional',
#  386: 'Twin Falls, ID: Joslin Field - Magic Valley Regional',
#  387: 'Tyler, TX: Tyler Pounds Regional',
#  388: 'Unalaska, AK: Unalaska Airport',
#  389: 'Valdosta, GA: Valdosta Regional',
#  390: 'Valparaiso, FL: Eglin AFB Destin Fort Walton Beach',
#  391: 'Vernal, UT: Vernal Regional',
#  392: 'Victoria, TX: Victoria Regional',
#  393: 'Visalia, CA: Visalia Municipal',
#  394: 'Waco, TX: Waco Regional',
#  395: 'Walla Walla, WA: Walla Walla Regional',
#  396: 'Washington, DC: Ronald Reagan Washington National',
#  397: 'Washington, DC: Washington Dulles International',
#  398: 'Waterloo, IA: Waterloo Regional',
#  399: 'Watertown, NY: Watertown International',
#  400: 'Watertown, SD: Watertown Regional',
#  401: 'Wenatchee, WA: Pangborn Memorial',
#  402: 'West Palm Beach/Palm Beach, FL: Palm Beach International',
#  403: 'West Yellowstone, MT: Yellowstone',
#  404: 'White Plains, NY: Westchester County',
#  405: 'Wichita Falls, TX: Sheppard AFB/Wichita Falls Municipal',
#  406: 'Wichita, KS: Wichita Dwight D Eisenhower National',
#  407: 'Williamsport, PA: Williamsport Regional',
#  408: 'Williston, ND: Sloulin Field International',
#  409: 'Williston, ND: Williston Basin International',
#  410: 'Wilmington, DE: New Castle',
#  411: 'Wilmington, NC: Wilmington International',
#  412: 'Worcester, MA: Worcester Regional',
#  413: 'Wrangell, AK: Wrangell Airport',
#  414: 'Yakima, WA: Yakima Air Terminal/McAllister Field',
#  415: 'Yakutat, AK: Yakutat Airport',
#  416: 'Youngstown/Warren, OH: Youngstown-Warren Regional',
#  417: 'Yuma, AZ: Yuma MCAS/Yuma International'}

# %%
df_1['carrier'] = encoder.fit_transform(df_1['carrier'])
carrier = {index : label for index, label in enumerate(encoder.classes_)}
carrier
# Out:
# C:\Users\tscot\AppData\Local\Temp\ipykernel_4404\1611633106.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['carrier'] = encoder.fit_transform(df_1['carrier'])
# {0: '9E',
#  1: 'AA',
#  2: 'AQ',
#  3: 'AS',
#  4: 'B6',
#  5: 'CO',
#  6: 'DH',
#  7: 'DL',
#  8: 'EV',
#  9: 'F9',
#  10: 'FL',
#  11: 'G4',
#  12: 'HA',
#  13: 'HP',
#  14: 'MQ',
#  15: 'NK',
#  16: 'NW',
#  17: 'OH',
#  18: 'OO',
#  19: 'QX',
#  20: 'RU',
#  21: 'TZ',
#  22: 'UA',
#  23: 'US',
#  24: 'VX',
#  25: 'WN',
#  26: 'XE',
#  27: 'YV',
#  28: 'YX'}

# %%
x = df_1.drop('late_aircraft_delay', axis=1)
y = df_1['late_aircraft_delay']

# %% [markdown]
# Exploratory Data Analysis

# %%
sn.set();
df.hist(figsize=(15,15));

# %%
sn.set()
plt.figure(figsize=(20,10))
sn.barplot(data=df, x = df.year, y = df.late_aircraft_delay)
plt.show()

# %% [markdown]
# MODEL

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=20,random_state=44)
print("x_train shape is:",x_train.shape)
print("x_test shape is:",x_test.shape)
print("y_train shape is:",y_train.shape)
print("y_test shape is:",y_test.shape)
# Out:
# x_train shape is: (317241, 20)
# x_test shape is: (20, 20)
# y_train shape is: (317241,)
# y_test shape is: (20,)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
RandomForestRegressorModel = RandomForestRegressor(n_estimators=100,max_depth=5, random_state=33)
RandomForestRegressorModel.fit(x_train, y_train)

print('Random Forest Regressor Train Score is : ' , RandomForestRegressorModel.score(x_train, y_train))
print('Random Forest Regressor Test Score is : ' , RandomForestRegressorModel.score(x_test, y_test))
#print('Random Forest Regressor No. of features are : ' , RandomForestRegressorModel.n_features_)
print('----------------------------------------------------')

y_pred = RandomForestRegressorModel.predict(x_test)
print('Predicted Value for Random Forest Regressor is : ' , y_pred[:10])
# Out:
# Random Forest Regressor Train Score is :  0.9735605538335649
# Random Forest Regressor Test Score is :  0.9675947267321965
# ----------------------------------------------------
# Predicted Value for Random Forest Regressor is :  [ 968.97955376 1453.21434989 3349.04559487  968.97955376  593.6514842
#  1444.26723898  968.97955376 2506.1271021   284.37932985 1186.44391197]

# %% [markdown]
# Evaluation Of Model

# %%
from sklearn.metrics import mean_squared_error
MSEValue = mean_squared_error(y_test, y_pred, multioutput='uniform_average') # it can be raw_values
print('Mean Squared Error Value is : ', MSEValue)
# Out:
# Mean Squared Error Value is :  1126843.6620416723

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9675947267321965
